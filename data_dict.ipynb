# %%
import pandas as pd

# %%
df = pd.read_json("assets/data_dict.json")
df.head()
# Out:
#      Field Name Data Type                                        Description  \
# 0     age_group    string                             Categorized age group
# 1           sex   char(1)                      Biological sex of the patient
# 2           chf      bool  History of congestive heart failure or left ve...
# 3  hypertension      bool                            History of hypertension
# 4      diabetes      bool                       History of diabetes mellitus
#
#                             Allowed Values Example  BPMN Task  \
# 0  '<18', '18-64', '65-74', '75-80','>=80'   65-74  CHADSVASC
# 1                 'M' (Male), 'F' (Female)       F  CHADSVASC
# 2                              True, False   False  CHADSVASC
# 3                              True, False    True  CHADSVASC
# 4                              True, False   False  CHADSVASC
#
#                     Rule Logik  UID BPMN TASK
# 0  Only one answer is possible  NaN       NaN
# ...
